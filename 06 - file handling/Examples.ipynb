# %%
username= input('Enter your username: ')
password= input('Enter your password: ')
print('username',username)
print('password',password)
# Out:
# Enter your username:  ayanabil11
# Enter your password:  123456789
# username ayanabil11
# password 123456789
